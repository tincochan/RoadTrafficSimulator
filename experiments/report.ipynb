# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_table("./1.data", sep=" ")
plt.plot(data['multiplier'], data['avg_speed'], '-o')

# %%
data = pd.read_table("./2.data", sep=" ")
plt.plot(data['it'], data['avg_speed'], '-o')

# %%
data = pd.read_table("./3.data", sep=" ")
data = data.sort(columns='it')
plt.plot(data['it'], data['avg_speed'], '-o')
# Out:
# Error: Jupyter cannot be started. Error attempting to locate jupyter: Data Science libraries jupyter and notebook are not installed in interpreter Python 3.8.1 64-bit.
# at b.startServer (c:\Users\Administrator\.vscode\extensions\ms-python.python-2020.7.94776\out\client\extension.js:48:297033)
# at processTicksAndRejections (internal/process/task_queues.js:85:5)
# at async b.createServer (c:\Users\Administrator\.vscode\extensions\ms-python.python-2020.7.94776\out\client\extension.js:48:296475)
# at async connect (c:\Users\Administrator\.vscode\extensions\ms-python.python-2020.7.94776\out\client\extension.js:48:431240)
# at async P.ensureConnectionAndNotebookImpl (c:\Users\Administrator\.vscode\extensions\ms-python.python-2020.7.94776\out\client\extension.js:24:457326)
# at async P.ensureConnectionAndNotebook (c:\Users\Administrator\.vscode\extensions\ms-python.python-2020.7.94776\out\client\extension.js:24:457004)
# at async P.clearResult (c:\Users\Administrator\.vscode\extensions\ms-python.python-2020.7.94776\out\client\extension.js:24:452887)
# at async P.reexecuteCell (c:\Users\Administrator\.vscode\extensions\ms-python.python-2020.7.94776\out\client\extension.js:24:439643)
# at async P.reexecuteCells (c:\Users\Administrator\.vscode\extensions\ms-python.python-2020.7.94776\out\client\extension.js:24:436061)
